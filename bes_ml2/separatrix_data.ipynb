# %%
import h5py
import numpy as np

# %%
separatrix_data = '/pscratch/sd/k/kevinsg/bes_ml_jobs/confinement_data/20241014.hdf5'  
# bes_data = '/pscratch/sd/k/kevinsg/bes_ml_jobs/confinement_data/20240429_final.hdf5'

# %%
def print_structure(name, obj):
    """Recursively prints the structure of the HDF5 group/dataset."""
    print('Path:', name)
    if isinstance(obj, h5py.Dataset):
        print('Type: Dataset')
        print('Shape:', obj.shape)
        print('Data Type:', obj.dtype)
        print('Attributes:')
        for attr_name, attr_value in obj.attrs.items():
            print(f'  {attr_name}: {attr_value}')
    elif isinstance(obj, h5py.Group):
        print('Type: Group')
        print('Attributes:')
        for attr_name, attr_value in obj.attrs.items():
            print(f'  {attr_name}: {attr_value}')
    print()

# %%
# Open the HDF5 file
with h5py.File(separatrix_data, 'r') as file:
    print("HDF5 file structure:")
    file.visititems(print_structure)
# Out:
# HDF5 file structure:
# Path: 149993
# Type: Group
# Attributes:
#   delz_avg: 1.5
#   inboard_column_channel_order: [ 1  9 17 25 33 41 49 57]
#   r_avg: 224.89999389648438
#   r_position: [221.51486 222.48042 223.44522 224.42003 225.40207 226.38687 227.38663
#  228.38928 221.51486 222.48042 223.44522 224.42003 225.40207 226.38687
#  227.38663 228.38928 221.51486 222.48042 223.44522 224.42003 225.40207
#  226.38687 227.38663 228.38928 221.51486 222.48042 223.44522 224.42003
#  225.40207 226.38687 227.38663 228.38928 221.51486 222.48042 223.44522
#  224.42003 225.40207 226.38687 227.38663 228.38928 221.51486 222.48042
#  223.44522 224.42003 225.40207 226.38687 227.38663 228.38928 221.51486
#  222.48042 223.44522 224.42003 225.40207 226.38687 227.38663 228.38928
#  221.51486 222.48042 223.44522 224.42003 225.40207 226.38687 227.38663
#  228.38928]
#   z_avg: -0.4000000059604645
#   z_position: [ 4.907141    4.9081454   4.9082713   4.906504    4.9073825   4.9075084
# ...

# %%
# Open the HDF5 file
with h5py.File(separatrix_data, 'r') as file:
    print("HDF5 file structure:")
    # file.visititems(print_structure)
    ex = file['184443']['3063']['separatrix']
    print(ex)
# Out:
# HDF5 file structure:
# <HDF5 dataset "separatrix": shape (2303001, 6, 2), type "<f8">

# %%
inference_data = '/pscratch/sd/k/kevinsg/bes_ml_jobs/exp_gill01/32263321/separatrix_inference_data.hdf5'

# %%
# Open the HDF5 file
with h5py.File(inference_data, 'r') as file:
    print("HDF5 file structure:")
    # file.visititems(print_structure)
    ex = file['batch_830']['time_points'][:]
    print(ex)
# Out:
# HDF5 file structure:
# [[1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
#  [1844491948]
# ...
